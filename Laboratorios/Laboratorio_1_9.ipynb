# %% [markdown]
# <img src="Archivos/miia.jpg" width=800x>
#
# # Laboratorio 1
#
# ## Desarrollo de una herramienta analítica usando solo Python
#
# Este laboratorio busca evaluar las habilidades relacionadas con la primera parte del curso, correspondiente a las primeras tres semanas. Este enunciado estará disponible desde la semana 2 y deberá entregarse al final de la semana 4 en el enlace correspondiente. Su desarrollo corresponde al 30% de la calificación total del curso.
#
# Esta actividad responde directamente al segundo objetivo del curso:
# * Implementar una herramienta analítica que permita responder una pregunta de negocio para un problema sencillo de analítica de datos, utilizando únicamente algorítmica básica en Python.
#
# Al desarrollar este laboratorio pondrás a prueba tus habilidades para:
# 1. Leer datos desde archivos.
# 2. Almacenar datos en  estructuras de Python.
# 3. Crear y llamar funciones correctamente.
# 4. Implementar condicionales diferenciando *if*, *elif* y *else*
# 5. Implementar ciclos diferenciando el propósito de *for* y *while*
# 6. Importar paquetes y utilizar sus funciones.
#
# **NOTAS:**
# - Te recomendamos leer por completo el enunciado del laboratorio antes de comenzar, de forma que tengas claro el propósito completo de la actividad, y puedas desarrollar tu solución apuntando a él desde el comienzo.

# %% [markdown]
# ## Contexto: exploración del potencial para asignar becas Uniandes
# La Universidad de los Andes se ha caracterizado por su compromiso con la generación de impacto en la sociedad a través de diferentes programas de becas. Programas como Quiero Estudiar, o Ser Pilo Paga, entre otros, han sido revolucionarios, al permitir que estudiantes de bajos recursos puedan acceder a una de las universidades privadas más importantes del país.
#
# Actualmente, la Universidad quiere evaluar el potencial impacto que tendrían algunos programas de *acción afirmativa* para asignación de becas, con base en información demográfica que ha obtenido a través de encuestas. Se cuenta con información respecto a la edad, género, estado civil, estrato socio-económico, región de proveniencia, desempeño académico y nivel de escolaridad de las personas que han respondido encuestas. Los encargados de diseñar el programa saben que utilizar criterios basados en este tipo de variables es un tema sensible, pero es necesario si se quieren focalizar las oportunidades en poblaciones menos representadas.
#
# El objetivo de este laboratorio es crear una herramienta computacional que permita a un tomador de decisiones explorar qué efecto podría tener el uso de diferentes reglas para seleccionar la población que sería beneficiaria de las becas. Puntualmente, se espera que, dadas unas reglas de selección (ej.: pertenecer a cierta región, rango de edad, etc.), la herramienta ofrezca información sobre la población potencialmente beneficiada, de forma que exista un sustento al momento de definir las reglas de selección.

# %% [markdown]
# ## 1. Obtención e inspección de archivos
#
# Los datos de encuestas fueron obtenidos como parte de un trabajo de campo, y por limitaciones tecnológicas, solo se cuenta con la información en archivos de texto plano. Cada archivo corresponde a una de las variables antes mencionadas y se puede garantizar que todos relacionan a las personas encuestadas en el mismo orden (i.e., la primera línea de todos los archivos corresponde a datos de la primera persona encuestada, la segunda línea a la segunda persona, etc.).
#
# Los archivos con los que se cuenta son:
# * *edades.txt*: un archivo ordenado con las edades de cada persona de la población encuestada
# * *género.txt*: un archivo ordenado con el género de cada persona de la población encuestada
# * *estado_civil.txt*: un archivo ordenado con el estado civil de cada persona de la población encuestada
# * *escolaridad.txt*: un archivo ordenado con el nivel de escolaridad de cada persona de la población encuestada
# * *estrato.txt*: un archivo ordenado con el estrato socio-económico de cada persona de la población encuestada
# * *region.txt*: un archivo ordenado con la región de proveniencia de cada persona de la población encuestada

# %% [markdown]
# **Misión 1**
#
# Poner en variables de Python la información que está en los archivos listados arriba.
#
# * *Versión base*: escribe línea a línea el código necesario para poner en variables de Python la información de cada uno de los archivos.
#
# * *Milla extra*: escribe una función que sea capaz de hacer lo anterior para un archivo y úsala en un ciclo para automatizar la lectura de los diferentes archivos.

# %%
import os
archivos = os.listdir('C:/Users/NataliaCifuentesBaqu/Archivos/')
print(archivos)
column = []
identificador=[]
edad = []
escolaridad = []
estado_civil = []
estrato = []
genero = []
promedio = []
region = []
registro = {}
tabla_datos = []
def leer_archivo(archivos):
    contador =-1
    for i in range(len(archivos)):
        name = archivos[i]
        filename = name.replace(".txt"," ")
        with open('C:/Users/NataliaCifuentesBaqu/Archivos/' + name, "r") as e:
            while (True):
                lineas = e.readline()
                linea = lineas.replace("\n","")
                contador += 1
                identificador.append(contador)
                if not linea:
                    break
                if i == 0:
                    edad.append(linea)
                elif i == 1:
                    escolaridad.append(linea)
                elif i == 2:
                    estado_civil.append(linea)
                elif i == 3:
                    estrato.append(linea)
                elif i == 4:
                    genero.append(linea)
                elif i == 5:
                    promedio.append(linea)
                elif i == 6:
                    region.append(linea)       
#Recorremos una de las listas partiendo de que todas tienen la misma longitud
    for j in range(len(edad)):
        registro = {"Id":identificador[j],"Edad": edad[j],"Escolaridad":str(escolaridad[j]),"Estado_civil": str(estado_civil[j]), 
                 "Estrato": estrato[j], "Genero": str(genero[j]),"Promedio": promedio[j], "Region": str(region[j])}
        tabla_datos.append(registro)
    #print(tabla_datos)
    return registro
#print(leer_archivo(archivos))

### Otra forma de lectura
#Se escribe como un diccionario de los archivos para tener listas de valores y obtener conteos

for i in range(len(archivos)):
    name = archivos[i]
    filename = name.replace(".txt"," ")
    with open('C:/Users/NataliaCifuentesBaqu/Archivos/' + name, "r") as e:
        column.append(e.read().split('\n'))
informacion = {"Edad": column[0], "Escolaridad": column[1], "Estado_C": column[2], 
               "Estrato": column[3], "Genero":column[4], "Promedio":column[5], "Region":column[6]}
#print(informacion)
# Out:
# ['edad.txt', 'escolaridad.txt', 'estado_civil.txt', 'estrato.txt', 'genero.txt', 'promedio.txt', 'region.txt']

# %% [markdown]
# **Misión 2**
#
# Reportar las principales características en los datos.
# * *Versión base*: utilizar métricas básicas como conteos o promedios por categorías en los datos.
# * *Milla extra*: utilizar visualizaciones simples como diagramas de barras, de pastel u otros.

# %%
# código

# importación de paquetes necesarios
import numpy as np
import matplotlib.pyplot as plt
import math as math
import statistics as es
from collections import Counter,defaultdict

#Calculo de conteos por categoria 
contador = 0
for lista in informacion.values(): 
    valores = list(Counter(lista).keys())
    conteo =  list(Counter(lista).values())
    contador += 1
    if contador > 1 and contador != 6:
        plt.pie(conteo, labels=valores)
        plt.title("Distribución Población ")
        plt.show()
        AgrupamientoCat = dict(zip(valores, conteo))
        print(AgrupamientoCat)
    
#Dado que los archivos se leen como cadenas de texto se realiza la conversión para 
#procesar los datos cuantitativos 

edad = [int(x) for x in column[0]]
estrato = [int(x) for x in column[3]]
promedio = [float(x) for x in column[5]]

#Calculo del promedio de edad  
print("El promedio de la edad de la población es: "+ str(round(es.mean(edad),0)))

#Se gráfica un histograma para identificar la distribución de la variable edad
#calculamos las frecuencias para 10 intervalos (bins=10)
#indicamos que los valores van de 18 a 80 
frecuencias, extremos = np.histogram(edad, bins=10, range=(18,81))
plt.hist(x=edad, bins=extremos, color='#F5CF8D', rwidth=0.95)
plt.title('Histograma de edades')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
plt.xticks(extremos)
#Mostrar el histograma 
plt.show()


#variablescuanti = [Estrato,]
#Se gráfica un diagrama de cajas para identificar la proporción de los datos y la mediana de las edades Q2 
plt.boxplot(promedio)
plt.title("Gráfico de distribución por cuartiles de promedios")
plt.ylabel('Promedio')
plt.show()    

frecuencias, extremos = np.histogram(promedio, bins=10, range=(1,5))
plt.hist(x=promedio, bins=extremos, color='#F2BF1D', rwidth=0.95)
plt.title('Histograma de Promedios')
plt.xlabel('Promedio')
plt.ylabel('Frecuencia')
plt.xticks(extremos)
#Mostrar el histograma 
plt.show()

#Se reccorre el diccionario de información con el fin de obtener graficos de 
#dispersión para analizar relaciones entre variables 

conteo_total = []
valores_total = []
for lista in informacion.values(): 
    contador = 0
    valores = list(Counter(lista).keys())
    conteo =  list(Counter(lista).values())
    if contador == 1 and contador == 5:
        AgrupamientoCat = dict(zip(valores, conteo))
        print(AgrupamientoCat)
    valores_total.append(valores)
    conteo_total.append(conteo)
    

#Grafico de Estrato Vs. Promedio
plt.scatter(estrato,promedio)
plt.xlabel("Estrato Socio Económico")
plt.ylabel("Promedio")
plt.show()

#Gráfico de Región Vs. Promedio
Regiones = valores_total[6]
Promedio = conteo_total[5]
plt.scatter(column[6], promedio, color='#F2BF1D')
plt.xlabel("Regiones")
plt.ylabel("Promedio")
plt.show()
# Out:
# {'Secundaria': 343, 'Profesional': 117, 'Primaria': 25, 'Maestria': 15}
# {'casada': 199, 'divorciada': 137, 'soltera': 148, 'viuda': 16}
# {'5': 13, '1': 111, '3': 156, '2': 185, '4': 35}
# {'masculino': 204, 'femenino': 251, 'otro': 6, 'no binario': 39}
# {'Andina': 142, 'Pacifica': 117, 'Orinoquia': 33, 'Caribe': 193, 'Amazonia': 15}
# El promedio de la edad de la población es: 49.0

# %% [markdown]
# ## 2. Abordaje de la pregunta de negocio
#
# El comité encargado de diseñar el programa de becas ha tenido dificultades para llegar a acuerdos. Algunos piensan que el criterio principal de selección debería ser respecto a lo económico y académico, sin importar otras características personales, mientras que otros piensan que considerar estas características es, de hecho, parte del espíritu del programa.
#
# * El primer grupo sugiere que se deben tomar en orden ascendente los estratos y elegir, en cada uno de ellos, al 2% de personas con promedio académico superior en esa sub-población, hasta que se agoten las becas disponibles. En caso de quedar becas disponibles al final del proceso, se repite el mismo esquema, considerando que ya no se tienen en cuenta las personas que hayan sido elegidas en rondas anteriores.
#
# * El segundo grupo sugiere que los recibidores de becas deben estar igualmente distribuidos entre las diferentes regiones y generos, considerando, por supuesto, que para cada una de esas sub-poblaciones, las personas elegidas sean las de mejores promedios académicos.
#
# Dado que las diferencias entre estos grupos obedecen a su entendimiento particular del problema, el presidente del comité propone utilizar los datos disponibles de las encuestas, sugiriendo que se analice qué características tendría la población de elegidos bajo cada uno de los dos criterios expuestos.

# %% [markdown]
# **Misión 3**
#
# Defina la pregunta de negocio y la pregunta de *analytics* para esta situación.

# %%
# respuesta en texto (solo leeremos los primeros 300 caracteres de la respuesta)

pregunta_negocio = '¿Cómo se debe realizar la distribución de becas de manera que la asignación evidencie transparencia y equidad de acuerdo con las características académicas y demográficas de los aspirantes, considerando las restricciones frente al número de becas y promoviendo la excelencia académica?'

pregunta_analytics = 'Teniendo en cuenta la distribución de las características cualitativas y cuantitativas de la población observada, establecer un modelo de distribución de becas que permita llegar a los diferentes grupos poblaciones que muestren los mejores promedios académicos utilizando distribuiciones por las variables de genero, estrato y region'

# %% [markdown]
# **Misión 4**
#
# Desarrollar un algoritmo que permita conocer la población que sería becada según los criterios propuestos por el *primer grupo* mencionado arriba.

# %%
# código
print("*****Ingrese el Número de Becas Disponibles*****")
Becas = input()
try:
    Becas = int(Becas)         
    print("*****Seleccione el porcentaje de Becas a Asignar*****")
    try:
        Porcentaje = input()
        p = int(Porcentaje)/100
    except:
        print("El porcentaje de Becas a asignar debe ser númerico, registre el valor")
        Porcentaje = input()
except:
    print("¡El número de becas disponibles debe ser númerico, registre el valor!")
    Becas = input()
elemento = {}
estrato1 =[]
estrato2 =[]
estrato3 =[]
estrato4 =[]
estrato5 =[]
ListaOrdenada1 = []
ListaOrdenada2 = []
ListaOrdenada3 = []
ListaOrdenada4 = []
ListaOrdenada5 = []
PoblacionBecados = []
seleccionado={}
llave = []
ContadorBecas = Becas
for i in range(len(tabla_datos)):
    elemento = tabla_datos[i]
    if elemento["Estrato"] == '1':
        estrato1.append(elemento)
    elif elemento["Estrato"] == '2':
        estrato2.append(elemento)
    elif elemento["Estrato"] == '3':
        estrato3.append(elemento)
    elif elemento["Estrato"] == '4':
        estrato4.append(elemento)
    elif elemento["Estrato"] == '5':
        estrato5.append(elemento)
ListaOrdenada1 = sorted(estrato1, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada2 = sorted(estrato2, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada3 = sorted(estrato3, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada4 = sorted(estrato4, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada5 = sorted(estrato5, key=lambda lis:lis["Promedio"], reverse = True)
#print(ListaOrdenada)
while ContadorBecas > 0:
    porcentaje1 = round(len(ListaOrdenada1)*p,0)
    print(porcentaje1)
    porcentaje2 = round(len(ListaOrdenada2)*p,0)
    porcentaje3 = round(len(ListaOrdenada3)*p,0)
    porcentaje4 = round(len(ListaOrdenada4)*p,0)
    porcentaje5 = round(len(ListaOrdenada5)*p,0)
    if porcentaje1 < 1:porcentaje1 = 1
    if porcentaje2 < 1:porcentaje2 = 1
    if porcentaje3 < 1:porcentaje3 = 1
    if porcentaje4 < 1:porcentaje4 = 1
    if porcentaje5 < 1:porcentaje5 = 1
    for j in range(len(ListaOrdenada1)):
        if j < porcentaje1:
            PoblacionBecados.append(ListaOrdenada1[j])
            ContadorBecas = ContadorBecas-1
            ListaOrdenada1.pop(j)
        else:
            break
    for j in range(len(ListaOrdenada2)):
        if j < porcentaje2:
            PoblacionBecados.append(ListaOrdenada2[j])
            ContadorBecas = ContadorBecas-1
            ListaOrdenada2.pop(j)
        else:
            break
    for j in range(len(ListaOrdenada3)):
        if j < porcentaje3:
            PoblacionBecados.append(ListaOrdenada3[j])
            ContadorBecas = ContadorBecas-1
            ListaOrdenada3.pop(j)
        else:
            break
    for j in range(len(ListaOrdenada4)):
        if j < porcentaje4:
            PoblacionBecados.append(ListaOrdenada4[j])
            ContadorBecas = ContadorBecas-1
            ListaOrdenada4.pop(j)
        else:
            break
    for j in range(len(ListaOrdenada5)):
        if j < porcentaje5:
            PoblacionBecados.append(ListaOrdenada5[j])
            ContadorBecas = ContadorBecas-1
            ListaOrdenada5.pop(j)
        else:
            break
print(PoblacionBecados)
# Out:
# *****Ingrese el Número de Becas Disponibles*****
# 20
# *****Seleccione el porcentaje de Becas a Asignar*****
# 2
# 2.0
# 2.0
# ...

# %% [markdown]
# **Misión 5**
#
# Desarrollar un algoritmo que permita conocer la población que sería becada según los criterios propuestos por el *segundo grupo* mencionado arriba.

# %%
##### código
print("*****Ingrese el Número de Becas Disponibles*****")
Becas = input()
try:
    Becas = int(Becas)         
    print("*****Seleccione el porcentaje de Becas a Asignar*****")
    try:
        Porcentaje = input()
        p = int(Porcentaje)/100
    except:
        print("El porcentaje de Becas a asignar debe ser númerico, registre el valor")
        Porcentaje = input()
except:
    print("¡El número de becas disponibles debe ser númerico, registre el valor!")
    Becas = input()
becas_grupo = round(Becas*p,0)
elemento = {}
AndinaH=[]
AndinaM=[]
AndinaN=[]
AndinaO=[]
OrinoquiaH=[]
OrinoquiaM=[]
OrinoquiaN=[]
OrinoquiaO=[]
CaribeH=[]
CaribeM=[]
CaribeN=[]
CaribeO=[]
PacificaH=[]
PacificaM=[]
PacificaN=[]
PacificaO=[]
AmazoniaH=[]
AmazoniaM=[]
AmazoniaN=[]
AmazoniaO=[]
PoblacionBecados2=[]
for i in range(len(tabla_datos)):
    elemento = tabla_datos[i]
    if elemento["Region"] == 'Andina' and elemento["Genero"] == "masculino":
        AndinaH.append(elemento)
    elif elemento["Region"] == 'Andina' and elemento["Genero"] == "femenino":
        AndinaM.append(elemento)
    elif elemento["Region"] == 'Andina' and elemento["Genero"] == "no binario":
        AndinaN.append(elemento)
    elif elemento["Region"] == 'Andina' and elemento["Genero"] == "otro":
        AndinaO.append(elemento)
    elif elemento["Region"] == 'Orinoquia' and elemento["Genero"] == "masculino":
        OrinoquiaH.append(elemento)
    elif elemento["Region"] == 'Orinoquia' and elemento["Genero"] == "femenino":
        OrinoquiaM.append(elemento)
    elif elemento["Region"] == 'Orinoquia' and elemento["Genero"] == "no binario":
        OrinoquiaN.append(elemento)
    elif elemento["Region"] == 'Orinoquia' and elemento["Genero"] == "otro":
        OrinoquiaO.append(elemento)
    elif elemento["Region"] == 'Caribe' and elemento["Genero"] == "masculino":
        CaribeH.append(elemento)
    elif elemento["Region"] == 'Caribe' and elemento["Genero"] == "femenino":
        CaribeM.append(elemento)
    elif elemento["Region"] == 'Caribe' and elemento["Genero"] == "no binario":
        CaribeN.append(elemento)
    elif elemento["Region"] == 'Caribe' and elemento["Genero"] == "otro":
        CaribeO.append(elemento)
    elif elemento["Region"] == 'Pacifica' and elemento["Genero"] == "masculino":
        PacificaH.append(elemento)
    elif elemento["Region"] == 'Pacifica' and elemento["Genero"] == "femenino":
        PacificaM.append(elemento)
    elif elemento["Region"] == 'Pacifica' and elemento["Genero"] == "no binario":
        PacificaN.append(elemento)
    elif elemento["Region"] == 'Pacifica' and elemento["Genero"] == "otro":
        PacificaO.append(elemento)
    elif elemento["Region"] == 'Amazonia' and elemento["Genero"] == "masculino":
        AmazoniaH.append(elemento)
    elif elemento["Region"] == 'Amazonia' and elemento["Genero"] == "femenino":
        AmazoniaM.append(elemento)
    elif elemento["Region"] == 'Amazonia' and elemento["Genero"] == "no binario":
        AmazoniaN.append(elemento)
    elif elemento["Region"] == 'Amazonia' and elemento["Genero"] == "otro":
        AmazoniaO.append(elemento)    
ListaOrdenada1 = sorted(AndinaH, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada2 = sorted(AndinaM, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada3 = sorted(AndinaN, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada4 = sorted(AndinaO, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada5 = sorted(OrinoquiaH, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada6 = sorted(OrinoquiaM, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada7 = sorted(OrinoquiaN, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada8 = sorted(OrinoquiaO, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada9 = sorted(CaribeH, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada10= sorted(CaribeM, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada11= sorted(CaribeN, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada12= sorted(CaribeO, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada13= sorted(PacificaH, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada14= sorted(PacificaM, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada15= sorted(PacificaN, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada16= sorted(PacificaO, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada17= sorted(AmazoniaH, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada18= sorted(AmazoniaM, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada19= sorted(AmazoniaN, key=lambda lis:lis["Promedio"], reverse = True)
ListaOrdenada20= sorted(AmazoniaO, key=lambda lis:lis["Promedio"], reverse = True)
#print(ListaOrdenada)
if becas_grupo < 1:becas_grupo = 1
for j in range(len(ListaOrdenada1)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada1[j])
for j in range(len(ListaOrdenada2)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada2[j])
for j in range(len(ListaOrdenada3)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada3[j])
for j in range(len(ListaOrdenada4)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada4[j])
for j in range(len(ListaOrdenada5)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada5[j])
for j in range(len(ListaOrdenada6)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada6[j])
for j in range(len(ListaOrdenada7)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada7[j])
for j in range(len(ListaOrdenada8)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada8[j])
for j in range(len(ListaOrdenada9)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada9[j])
for j in range(len(ListaOrdenada10)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada10[j])
for j in range(len(ListaOrdenada11)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada11[j])
for j in range(len(ListaOrdenada12)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada12[j])
for j in range(len(ListaOrdenada13)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada13[j])
for j in range(len(ListaOrdenada14)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada14[j])
for j in range(len(ListaOrdenada15)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada15[j])
for j in range(len(ListaOrdenada16)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada16[j])
for j in range(len(ListaOrdenada17)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada17[j])
for j in range(len(ListaOrdenada18)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada18[j])
for j in range(len(ListaOrdenada19)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada19[j])
for j in range(len(ListaOrdenada20)):
    if j < becas_grupo:
        PoblacionBecados2.append(ListaOrdenada20[j])
print(PoblacionBecados2)
# Out:
# *****Ingrese el Número de Becas Disponibles*****
# 30
# *****Seleccione el porcentaje de Becas a Asignar*****
# 3
# ...

# %% [markdown]
# **Misión 6**
#
# Desarrollar un algoritmo, a partir de lo anterior, cuyo resultado permita al comité comparar fácilmente las características de las dos poblaciones hipotéticas que recibirían becas.
#
# *Ayuda*: considera utilizar tus implementaciones de la *Misión 2* para facilitar esta misión.

# %%
# código para presentar los resultados graficamente 
PoblacionEdad =[]
PoblacionEstratos = []
PoblacionEscolaridad =[]
PoblacionEstCivil = []
PoblacionRegion = []
PoblacionPromedio = []
PoblacionGenero = []
for dicc in PoblacionBecados:
    EdadesSel = int(dicc["Edad"])
    EstratosSel = int(dicc["Estrato"])
    EscSel = dicc["Escolaridad"]
    EstCivSel = dicc["Estado_civil"]
    GenSel = dicc["Genero"]
    PromSel = float(dicc["Promedio"])
    RegSel = dicc["Region"]
    PoblacionEdad.append(EdadesSel)
    PoblacionEstratos.append(EstratosSel)
    PoblacionEscolaridad.append(EscSel)
    PoblacionEstCivil.append(EstCivSel)
    PoblacionGenero.append(GenSel)
    PoblacionPromedio.append(PromSel)
    PoblacionRegion.append(RegSel)
ResEstrato = dict(zip(PoblacionEstratos,map(lambda x: PoblacionEstratos.count(x),PoblacionEstratos)))
ResEsc = dict(zip(PoblacionEscolaridad,map(lambda x: PoblacionEscolaridad.count(x),PoblacionEscolaridad)))
ResEstCiv = dict(zip(PoblacionEstCivil,map(lambda x: PoblacionEstCivil.count(x),PoblacionEstCivil)))
ResGen = dict(zip(PoblacionGenero,map(lambda x: PoblacionGenero.count(x),PoblacionGenero)))
ResReg = dict(zip(PoblacionRegion,map(lambda x: PoblacionRegion.count(x),PoblacionRegion)))
print(ResEstrato)
plt.pie(list(Counter(ResEstrato).values()), labels=list(Counter(ResEstrato).keys()))
plt.title("Distribución Población Becados Grupo 1")
plt.show()
print(ResEsc)
plt.pie(list(Counter(ResEsc).values()), labels=list(Counter(ResEsc).keys()))
plt.title("Distribución Población Becados Grupo 1")
plt.show()
print(ResEstCiv)
plt.pie(list(Counter(ResEstCiv).values()), labels=list(Counter(ResEstCiv).keys()))
plt.title("Distribución Población Becados Grupo 1")
plt.show()
print(ResGen)
plt.pie(list(Counter(ResGen).values()), labels=list(Counter(ResGen).keys()))
plt.title("Distribución Población Becados Grupo 1")
plt.show()
print(ResReg)
plt.pie(list(Counter(ResReg).values()), labels=list(Counter(ResReg).keys()))
plt.title("Distribución Región Becados Grupo 1")
plt.show()

#Se gráfica un histograma para identificar la distribución de la variable edad en las becas asignadas de acuerdo con el metodo 1
#calculamos las frecuencias para 6 intervalos
#indicamos que los valores van de 18 a 80 
frecuencias, extremos = np.histogram(PoblacionEdad, bins=8, range=(18,81))
plt.hist(x=PoblacionEdad, bins=extremos, color='#F5CF8D', rwidth=0.75)
plt.title('Frecuencia de Edad Becados por Estrato')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
plt.xticks(extremos)
plt.show()
#Se gráfica un histograma para identificar la distribución de la variable promedio en las becas asignadas de acuerdo con el metodo 1
frecuencias, extremos = np.histogram(PoblacionPromedio, bins=5, range=(4.5,5.0))
plt.hist(x=PoblacionPromedio, bins=extremos, color='#F5CE1F', rwidth=0.75)
plt.title('Frecuencia de Promedios Becados por Estrato')
plt.xlabel('Promedio')
plt.ylabel('Frecuencia')
plt.xticks(extremos)
plt.show()


##Código para presentar el análisis gráfico que corresponde a la selección de Becados de acuerdo a las politicas del grupo 2
PoblacionEdad1 =[]
PoblacionEstratos1 = []
PoblacionEscolaridad1 =[]
PoblacionEstCivil1 = []
PoblacionRegion1 = []
PoblacionPromedio1 = []
PoblacionGenero1 = []
for dicc in PoblacionBecados2:
    EdadesSel = int(dicc["Edad"])
    EstratosSel = int(dicc["Estrato"])
    EscSel = dicc["Escolaridad"]
    EstCivSel = dicc["Estado_civil"]
    GenSel = dicc["Genero"]
    PromSel = float(dicc["Promedio"])
    RegSel = dicc["Region"]
    PoblacionEdad1.append(EdadesSel)
    PoblacionEstratos1.append(EstratosSel)
    PoblacionEscolaridad1.append(EscSel)
    PoblacionEstCivil1.append(EstCivSel)
    PoblacionGenero1.append(GenSel)
    PoblacionPromedio1.append(PromSel)
    PoblacionRegion1.append(RegSel)
ResEstrato = dict(zip(PoblacionEstratos1,map(lambda x: PoblacionEstratos1.count(x),PoblacionEstratos1)))
ResEsc = dict(zip(PoblacionEscolaridad1,map(lambda x: PoblacionEscolaridad1.count(x),PoblacionEscolaridad1)))
ResEstCiv = dict(zip(PoblacionEstCivil1,map(lambda x: PoblacionEstCivil1.count(x),PoblacionEstCivil1)))
ResGen = dict(zip(PoblacionGenero1,map(lambda x: PoblacionGenero1.count(x),PoblacionGenero1)))
ResReg = dict(zip(PoblacionRegion1,map(lambda x: PoblacionRegion1.count(x),PoblacionRegion1)))
print(ResEstrato)
plt.pie(list(Counter(ResEstrato).values()), labels=list(Counter(ResEstrato).keys()))
plt.title("Distribución Población Becados Grupo 2")
plt.show()
print(ResEsc)
plt.pie(list(Counter(ResEsc).values()), labels=list(Counter(ResEsc).keys()))
plt.title("Distribución Población Becados Grupo 2")
plt.show()
print(ResEstCiv)
plt.pie(list(Counter(ResEstCiv).values()), labels=list(Counter(ResEstCiv).keys()))
plt.title("Distribución Población Becados Grupo 2")
#plt.show()
print(ResGen)
plt.pie(list(Counter(ResGen).values()), labels=list(Counter(ResGen).keys()))
plt.title("Distribución Población Becados Grupo 2")
plt.show()
print(ResReg)
plt.pie(list(Counter(ResReg).values()), labels=list(Counter(ResReg).keys()))
plt.title("Distribución Región Becados Grupo 2")
plt.show()

#Se gráfica un histograma para identificar la distribución de la variable edad en las becas asignadas de acuerdo con el metodo 1
#calculamos las frecuencias para 6 intervalos
#indicamos que los valores van de 18 a 80 
frecuencias, extremos = np.histogram(PoblacionEdad1, bins=8, range=(18,81))
plt.hist(x=PoblacionEdad1, bins=extremos, color='#F5CF8D', rwidth=0.75)
plt.title('Frecuencia de Edad Becados por Región y Género')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
plt.xticks(extremos)
plt.show()
#Se gráfica un histograma para identificar la distribución de la variable promedio en las becas asignadas de acuerdo con el metodo 1
frecuencias, extremos = np.histogram(PoblacionPromedio1, bins=4, range=(3.8,5.0))
plt.hist(x=PoblacionPromedio1, bins=extremos, color='#F5CE1F', rwidth=0.75)
plt.title('Frecuencia de Promedios Becados por Región y Género')
plt.xlabel('Promedio')
plt.ylabel('Frecuencia')
plt.xticks(extremos)
plt.show()
# Out:
# {1: 4, 2: 8, 3: 6, 4: 2, 5: 2}
# {'Secundaria': 14, 'Profesional': 6, 'Primaria': 1, 'Maestria': 1}
# {'soltera': 10, 'casada': 7, 'divorciada': 4, 'viuda': 1}
# {'masculino': 8, 'femenino': 13, 'no binario': 1}
# {'Pacifica': 6, 'Caribe': 3, 'Andina': 10, 'Amazonia': 2, 'Orinoquia': 1}
# {1: 5, 2: 8, 5: 1, 3: 3, 4: 1}
# {'Secundaria': 15, 'Profesional': 3}
# {'casada': 8, 'soltera': 6, 'divorciada': 4}
# {'masculino': 5, 'femenino': 5, 'no binario': 4, 'otro': 4}
# {'Andina': 4, 'Orinoquia': 3, 'Caribe': 4, 'Pacifica': 3, 'Amazonia': 4}

# %% [markdown]
# ## 3. Desarrollo de una solución analítica
#
# Reconociendo la complejidad de este problema (que no permite reducirlo a una dicotomía) y viendo el potencial del análisis de datos para enriquecer la discusión y los insumos para tomar decisiones, el comité ha solicitado una herramienta analítica que les permita . Sus requerimientos son:
#
# * La herramienta debe permitir ingresar una política de selección de becados.
#     * Se debe poder elegir el rango de edad de los aspirantes.
#     * Se debe poder elegir qué proporción de las becas se asigna a cada género, a cada estrato, o a cada región (pero sólo debe elegirse uno de estos criterios).
# * La herramienta debe generar un resultado que permita al comité analizar las características de la población potencialmente elegida si se usara la política ingresada.
#
# **Misión 7**
#
# Desarrollar, a partir de lo construido hasta el momento, un algoritmo que permita cumplir con los requerimientos del comité.

# %%
print("*********************************************************************************")
print("*Herramienta para el Comité de Selección de Becas de la Universidad de Los Andes*")
print("*********************************************************************************")
print("*****Ingrese el Número de Becas Disponibles*****")
Becas = input()
try:
    Becas = int(Becas)         
    print("*****Seleccione el porcentaje de Becas a Asignar*****")
    Porcentaje = input()
    try:
        p = int(Porcentaje)/100
        print("El porcentaje asignado fue: "+str(Porcentaje)+"%")
        print("seleccione el criterio para asignar las becas")
        print ("1. Por Genero      2. Por Región     3. Por Edad      4. Por Estrato")
        Criterio = input()
        if Criterio == str(3):
            print("seleccione los rangos de edades para asignar las becas")
            print("1. 18 a 28 años   2. 29 a 40 años   3. 41 a 51 años  4. 52 en adelante   5. Todas las edades")
            Rango = input()
            try: 
                Rango = int(Rango)
                print(Rango)
            except:
                print("¡La opción seleccionada no es valida!")
                print("¡Ingrese un valor valido!")
                Rango = input()
    except:
        print("¡Ingrese un valor númerico para indicar el porcentaje de becas!")
        Porcentaje = input()
except:
    print("¡El número de becas disponibles debe ser númerico, registre el valor!")
    Becas = input()
ContadorBecas = Becas
elemento = {}
Masculino = []
Femenino = []
NoBinario = []
Otro =[]
Andina = []
Caribe = []
Amozonia = []
Orinoquia = []
Pacifico = []
RangoEdad = []
PoblacionBecados3 = []
if Criterio == str(1):
    for i in range(len(tabla_datos)):
        elemento = tabla_datos[i]
        if elemento["Genero"] == 'masculino':
            Masculino.append(elemento)
        elif elemento["Genero"] == 'femenino':
            Femenino.append(elemento)
        elif elemento["Genero"] == 'no binario':
            NoBinario.append(elemento)
        elif elemento["Genero"] == 'otro':
            Otro.append(elemento)
    ListaOrdenada1 = sorted(Masculino, key=lambda lis:lis["Promedio"], reverse = True)
    ListaOrdenada2 = sorted(Femenino, key=lambda lis:lis["Promedio"], reverse = True)
    ListaOrdenada3 = sorted(NoBinario, key=lambda lis:lis["Promedio"], reverse = True)
    ListaOrdenada4 = sorted(Otro, key=lambda lis:lis["Promedio"], reverse = True)
elif Criterio == str(2):
    for i in range(len(tabla_datos)):
        elemento = tabla_datos[i]
        if elemento["Region"] == 'Andina':
            Andina.append(elemento)
        elif elemento["Region"] == 'Caribe':
            Caribe.append(elemento)
        elif elemento["Region"] == 'Amazonia':
            Amozonia.append(elemento)
        elif elemento["Region"] == 'Orinoquia':
            Orinoquia.append(elemento)
        elif elemento["Region"] == 'Pacifica':
            Pacifico.append(elemento)
    ListaOrdenada1 = sorted(Andina, key=lambda lis:lis["Promedio"], reverse = True)
    ListaOrdenada2 = sorted(Caribe, key=lambda lis:lis["Promedio"], reverse = True)
    ListaOrdenada3 = sorted(Amozonia, key=lambda lis:lis["Promedio"], reverse = True)
    ListaOrdenada4 = sorted(Orinoquia, key=lambda lis:lis["Promedio"], reverse = True)
    ListaOrdenada5 = sorted(Pacifico, key=lambda lis:lis["Promedio"], reverse = True)
elif Criterio == str(3):
    if Rango == 1:
        for i in range(len(tabla_datos)):
            elemento = tabla_datos[i]
            if int(elemento["Edad"]) >= 18 and int(elemento["Edad"]) <= 28:
                RangoEdad.append(elemento)
        ListaOrdenada1 = sorted(RangoEdad, key=lambda lis:lis["Promedio"], reverse = True)
    elif Rango == 2:
        for i in range(len(tabla_datos)):
            elemento = tabla_datos[i]
            if int(elemento["Edad"]) >=  28 and int(elemento["Edad"]) <= 40:
                RangoEdad.append(elemento)
        ListaOrdenada1 = sorted(RangoEdad, key=lambda lis:lis["Promedio"], reverse = True)
    elif Rango == 3:
        for i in range(len(tabla_datos)):
            elemento = tabla_datos[i]
            if int(elemento["Edad"]) >=  40 and int(elemento["Edad"]) <= 51:
                RangoEdad.append(elemento)
        ListaOrdenada1 = sorted(RangoEdad, key=lambda lis:lis["Promedio"], reverse = True)
    elif Rango == 4:
        for i in range(len(tabla_datos)):
            elemento = tabla_datos[i]
            if int(elemento["Edad"]) >= 51:
                RangoEdad.append(elemento)
        ListaOrdenada1 = sorted(RangoEdad, key=lambda lis:lis["Promedio"], reverse = True)       
    elif Rango == 5:
        for i in range(len(tabla_datos)):
            elemento = tabla_datos[i]
            RangoEdad.append(elemento)
        ListaOrdenada1 = sorted(RangoEdad, key=lambda lis:lis["Promedio"], reverse = True)
elif Criterio == str(4):
    for i in range(len(tabla_datos)):
        elemento = tabla_datos[i]
        if elemento["Estrato"] == '1':
            estrato1.append(elemento)
        elif elemento["Estrato"] == '2':
            estrato2.append(elemento)
        elif elemento["Estrato"] == '3':
            estrato3.append(elemento)
        elif elemento["Estrato"] == '4':
            estrato4.append(elemento)
        elif elemento["Estrato"] == '5':
            estrato5.append(elemento)
    ListaOrdenada1 = sorted(estrato1, key=lambda lis:lis["Promedio"], reverse = True)
    ListaOrdenada2 = sorted(estrato2, key=lambda lis:lis["Promedio"], reverse = True)
    ListaOrdenada3 = sorted(estrato3, key=lambda lis:lis["Promedio"], reverse = True)
    ListaOrdenada4 = sorted(estrato4, key=lambda lis:lis["Promedio"], reverse = True)
    ListaOrdenada5 = sorted(estrato5, key=lambda lis:lis["Promedio"], reverse = True)
while ContadorBecas > 0:
    if len(ListaOrdenada1) > 0:
        porcentaje1 = round(len(ListaOrdenada1)*p,0)
        if porcentaje1 < 1:porcentaje1 = 1
        for j in range(len(ListaOrdenada1)):
            if j < porcentaje1:
                PoblacionBecados3.append(ListaOrdenada1[j])
                ContadorBecas = ContadorBecas-1
                ListaOrdenada1.pop(j)
            else:
                break
    elif len(ListaOrdenada2) > 0:
        porcentaje2 = round(len(ListaOrdenada2)*p,0)
        if porcentaje2 < 1:porcentaje1 = 1
        for j in range(len(ListaOrdenada2)):
            if j < porcentaje2:
                PoblacionBecados3.append(ListaOrdenada2[j])
                ContadorBecas = ContadorBecas-1
                ListaOrdenada2.pop(j)
            else:
                break
    elif len(ListaOrdenada3) > 0:  
        print(len(ListaOrdenada3))
        porcentaje3 = round(len(ListaOrdenada3)*p,0)
        if porcentaje3 < 1:porcentaje3 = 1
        for j in range(len(ListaOrdenada3)):
            if j < porcentaje3:
                PoblacionBecados3.append(ListaOrdenada3[j])
                ContadorBecas = ContadorBecas-1
                ListaOrdenada3.pop(j)
            else:
                break
    elif len(ListaOrdenada4) > 0:     
        print(len(ListaOrdenada4))
        porcentaje4 = round(len(ListaOrdenada4)*p,0)           
        if porcentaje4 < 1:porcentaje4 = 1
        for j in range(len(ListaOrdenada4)):
            if j < porcentaje4:
                PoblacionBecados3.append(ListaOrdenada4[j])
                ContadorBecas = ContadorBecas-1
                ListaOrdenada4.pop(j)
            else:
                break
    elif len(ListaOrdenada5) > 0: 
        print(len(ListaOrdenada5))
        porcentaje5 = round(len(ListaOrdenada5)*p,0)
        if porcentaje5 < 1:porcentaje5 = 1
        for j in range(len(ListaOrdenada5)):
            if j < porcentaje5:
                PoblacionBecados3.append(ListaOrdenada5[j])
                ContadorBecas = ContadorBecas-1
                ListaOrdenada5.pop(j)
            else:
                break
print("Esta es la población becada de acuerdo al criterio seleccionado, para las becas disponibles" + str(PoblacionBecados3))
print("La cantidad de becas asignadas de acuerdo con el criterio seleccionado es "+ str(len(PoblacionBecados3)))
PoblacionEdad3 =[]
PoblacionEstratos3 = []
PoblacionEscolaridad3 =[]
PoblacionEstCivil3 = []
PoblacionRegion3 = []
PoblacionPromedio3 = []
PoblacionGenero3 = []
for dicc in PoblacionBecados3:
    EdadesSel3 = int(dicc["Edad"])
    EstratosSel3 = int(dicc["Estrato"])
    EscSel3 = dicc["Escolaridad"]
    EstCivSel3 = dicc["Estado_civil"]
    GenSel3 = dicc["Genero"]
    PromSel3 = float(dicc["Promedio"])
    RegSel3 = dicc["Region"]
    PoblacionEdad3.append(EdadesSel3)
    PoblacionEstratos3.append(EstratosSel3)
    PoblacionEscolaridad3.append(EscSel3)
    PoblacionEstCivil3.append(EstCivSel3)
    PoblacionGenero3.append(GenSel3)
    PoblacionPromedio3.append(PromSel3)
    PoblacionRegion3.append(RegSel3)
ResEstrato1 = dict(zip(PoblacionEstratos3,map(lambda x: PoblacionEstratos3.count(x),PoblacionEstratos3)))
ResEsc1 = dict(zip(PoblacionEscolaridad3,map(lambda x: PoblacionEscolaridad3.count(x),PoblacionEscolaridad3)))
ResEstCiv1 = dict(zip(PoblacionEstCivil3,map(lambda x: PoblacionEstCivil3.count(x),PoblacionEstCivil3)))
ResGen1 = dict(zip(PoblacionGenero3,map(lambda x: PoblacionGenero3.count(x),PoblacionGenero3)))
ResReg1 = dict(zip(PoblacionRegion3,map(lambda x: PoblacionRegion3.count(x),PoblacionRegion3)))
ResEdad1 = dict(zip(PoblacionEdad3,map(lambda x: PoblacionEdad3.count(x),PoblacionEdad3)))
ResProm1 = dict(zip(PoblacionPromedio3,map(lambda x: PoblacionPromedio3.count(x),PoblacionPromedio3)))
print("La distribución de las becas por Estrato para la opción seleccionada es: "+ str(ResEstrato1))
print("La distribución de las becas por Escolaridad para la opción seleccionada es: "+ str(ResEsc1))
print("La distribución de las becas por Estado Civil para la opción seleccionada es: "+ str(ResEstCiv1))
print("La distribución de las becas por Región para la opción seleccionada es: "+ str(ResReg1))
print("La distribución de las becas por Edad para la opción seleccionada es: "+ str(ResEdad1))
print("La distribución de las becas por Promedio para la opción seleccionada es: "+ str(ResProm1))
print("El promedio máximo de los becados es: " + str(max(PoblacionPromedio3)))
print("El promedio mínimo de los becados es: " + str(min(PoblacionPromedio3)))

frecuencias, extremos = np.histogram(PoblacionEdad3, bins=8, range=(18,81))
plt.hist(x=PoblacionEdad3, bins=extremos, color='#F5CF8D', rwidth=0.75)
plt.title('Frecuencia de Edad Becados')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
plt.xticks(extremos)
plt.show()
# Out:
# *********************************************************************************
# *Herramienta para el Comité de Selección de Becas de la Universidad de Los Andes*
# *********************************************************************************
# *****Ingrese el Número de Becas Disponibles*****
# 30
# *****Seleccione el porcentaje de Becas a Asignar*****
# 2
# El porcentaje asignado fue: 2%
# seleccione el criterio para asignar las becas
# 1. Por Genero      2. Por Región     3. Por Edad      4. Por Estrato
# 2
# ...

# %% [markdown]
# **Misión 8**
#
# Proponer, con base en tu propio uso de la herramienta, una política de ingreso que consideres apropiada dado el contexto proporcionado. Si lo crees adecuado, explica, máximo 500 caracteres, las virtudes de tu propuesta (esto puede estar soportado en los datos, o no).

# %%
# respuesta en texto (solo leeremos los primeros 300 caracteres de la respuesta)

respuesta = 'La distribución es más flexible y eventualmente equitativa en el escenario propuesto por el grupo 2 donde se tiene equidad frente al número de becas asignadas por región y se amplia el rango de promedios de las personas becadas, sin embargo, la asignación podría hacerse asignando el mismo número de becas a todos los estratos en cada región'
print(len(respuesta))
# Out:
# 341

# %% [markdown]
# **Misión 9**
#
# Ejecutar el algoritmo desarrollado en la *Misión 7* sobre la política que sugieres proponer al comité. Explicar claramente tus conlusiones con el soporte de los resultados de la herramienta.

# %%
# código

conclusion = "Considerando la herramienta para la selección de becas, se tiene siempre la posibilidad de seleccionar el número de becas a asignar y el porcentaje de becas que se debe asignar a los subgrupos de la población de acuerdo con el criterio a asignar. La distribución propuesta cuando se utiliza el criterio por Genero se presenta a continuación: La distribución de las becas por Estrato para la opción seleccionada es: {1: 8, 3: 8, 4: 1, 2: 3}. La distribución de las becas por Escolaridad para la opción seleccionada es: {'Secundaria': 14, 'Profesional': 6} La distribución de las becas por Estado Civil para la opción seleccionada es: {'soltera': 10, 'divorciada': 2, 'casada': 8} La distribución de las becas por Región para la opción seleccionada es: {'Pacífica': 7, 'Andina': 7, 'Caribe': 3, 'Amazonia': 1, 'Orinoquia': 2} Para todas las distribuciones se evidencia que los promedios máximo y mínimo se mantienen entre 5.0 y 3.7 respectivamente, adicionalmente dado que la distribución siempre se realiza de acuerdo a la distribución inicial de la población mostrada en el ítem 2, se considera que cualquier criterio resultaría equitativo, sin embargo, podría excluir a un subgrupo de otra condición demográfica, como es el caso del criterio Genero, donde no se seleccionan estratos 2 que corresponde a la mayor parte de la población. Una vez realizados todos los ejercicios con la aplicación de asignación de becas, se considera que el mejor criterio de asignación es la región, donde se presentan distribución equitativa para los subgrupos de las otras características demográficas evaluadas."
print(conclusion)
# Out:
# Considerando la herramienta para la selección de becas, se tiene siempre la posibilidad de seleccionar el número de becas a asignar y el porcentaje de becas que se debe asignar a los subgrupos de la población de acuerdo con el criterio a asignar. La distribución propuesta cuando se utiliza el criterio por Genero se presenta a continuación: La distribución de las becas por Estrato para la opción seleccionada es: {1: 8, 3: 8, 4: 1, 2: 3}. La distribución de las becas por Escolaridad para la opción seleccionada es: {'Secundaria': 14, 'Profesional': 6} La distribución de las becas por Estado Civil para la opción seleccionada es: {'soltera': 10, 'divorciada': 2, 'casada': 8} La distribución de las becas por Región para la opción seleccionada es: {'Pacífica': 7, 'Andina': 7, 'Caribe': 3, 'Amazonia': 1, 'Orinoquia': 2} Para todas las distribuciones se evidencia que los promedios máximo y mínimo se mantienen entre 5.0 y 3.7 respectivamente, adicionalmente dado que la distribución siempre se 
# ...

# %% [markdown]
# ## Referencias
# * Discriminación Positiva<br>
# https://es.wikipedia.org/wiki/Discriminaci%C3%B3n_positiva
# * Análisis de formulación del programa “Ser Pilo Paga”<br>
# https://repository.urosario.edu.co/handle/10336/12526
# * La acción afirmativa en la Universidad de los Andes: El caso del programa "Oportunidades para talentos nacionales"<br> http://www.scielo.org.co/scielo.php?script=sci_arttext&pid=S0123-885X2004000300005
# * Acción afirmativa y equidad: un análisis desde la propuesta de Thomas Nagel<br>
# http://www.scielo.org.mx/scielo.php?script=sci_arttext&pid=S2007-24062016000200049

# %% [markdown]
# ## Créditos

# %% [markdown]
# Camilo Gómez - 11/06/21<br>
# *Revisado*: 25/08/21
